# %%
import os 
os.environ['CUDA_VISIBLE_DEVICES'] = '7'
import importlib
import ErrorDetector as ed
importlib.reload(ed)

# %%
ct='/mnt/sdc/pedro/ErrorDetection/cropped_liver_cts/BDMAP_00001399/ct.nii.gz'
y2='/mnt/sdc/pedro/ErrorDetection/cropped_liver_cts/BDMAP_00001399/segmentations/liver.nii.gz'
y1='../../AbdomenAtlasBeta/BDMAP_00001399/segmentations/liver.nii.gz'

importlib.reload(ed)
ed.project_and_compare(ct,y1,y2,window='skeleton')

# %% [markdown]
# # Systematic evaluation Kidneys

# %%
import os
os.environ['TRANSFORMERS_CACHE'] = './HFCache'
os.environ['HF_HOME'] = './HFCache'
os.environ['CUDA_VISIBLE_DEVICES'] = '7'

import ErrorDetector as ed
import importlib 
import os
importlib.reload(ed)

annos='../compose_BetaGT_ProGT/kidneys/'


ed.SystematicComparisonLMDeploySepFigures(pth=annos,size=448,organ='kidneys', 
                                        dice_check=True,save_memory=True,shuffle=True,
                                        base_url='http://0.0.0.0:8000/v1',
                                        window='skeleton')

# %%
import os
os.environ['TRANSFORMERS_CACHE'] = './HFCache'
os.environ['HF_HOME'] = './HFCache'
os.environ['CUDA_VISIBLE_DEVICES'] = '7'

import ErrorDetector as ed
import importlib 
import os
importlib.reload(ed)

annos='../compose_nnUnet_ProGT/kidneys/'


ed.SystematicComparisonLMDeploySepFigures(pth=annos,size=448,organ='kidneys', 
                                        dice_check=True,save_memory=True,shuffle=True,
                                        base_url='http://0.0.0.0:8000/v1',
                                        window='skeleton')

# %%
import os
os.environ['TRANSFORMERS_CACHE'] = './HFCache'
os.environ['HF_HOME'] = './HFCache'
os.environ['CUDA_VISIBLE_DEVICES'] = '7'

import ErrorDetector as ed
import importlib 
import os
importlib.reload(ed)

annos='../compose_nnUnet_ProGT/kidneys/'


ed.SystematicComparisonLMDeploySepFigures(pth=annos,size=448,organ='kidneys', 
                                        dice_check=True,save_memory=True,shuffle=True,
                                        base_url='http://0.0.0.0:8000/v1',
                                        window='skeleton',superpose=True)

# %%
#Kidneys:

#Accuracy:  Could get very high accuracy with qwen , 90-100%
#aorta: bad accuracy, most 70%. Could have 90% with the following prompt and sending the 2 images together in 1 prompt:


Compare2ImagesGOOD='Check out these 2 images. In which one does the red shape come further up, image 1 or image 2?'

# %% [markdown]
# # Aorta

# %%
import os
os.environ['TRANSFORMERS_CACHE'] = './HFCache'
os.environ['HF_HOME'] = './HFCache'
os.environ['CUDA_VISIBLE_DEVICES'] = '7'

import ErrorDetector as ed
import importlib 
import os
importlib.reload(ed)

annos='../compose_BetaGT_ProGT/aorta/'



ed.SystematicComparisonLMDeploySepFigures(pth=annos,size=512,organ='aorta', dice_check=True,save_memory=True, shuffle=True,comparison_window='bone',solid_overlay=True,
                                          multi_image_prompt_2=True
                                          )
# Out:
# BDMAP_00003976_ct_window_bone_axis_1_aorta.png
# Best is: 1
# 2D dice coefficient between 2 projections on axis 1: 0.8339322805404663
# clean: ../compose_BetaGT_ProGT/aorta/BDMAP_00003976_ct_window_skeleton_axis_1_aorta.png
# Initialized model and client.
# Image resized to: (427, 512)
# Top pixel: (0, 0, 0)
# Image Size (WxH) in prompt: (427, 512), File Size: 132476 bytes
# Number of images in the conversation: 1
# Length of img_file_list: 1
# Text: The image I am sending is frontal projections of one CT scan, focusing on showing the skeleton. Look at it carefully, and answer the questions below:
# Q1- Which bones are on the top of the image? Bones are on its bottom?
# Q2- Which of the following landmarks are present in the image? Answer ‘yes’ or ‘no’ using the template below, substituting  _ by Yes or No:
# ...

# %%
import os
os.environ['TRANSFORMERS_CACHE'] = './HFCache'
os.environ['HF_HOME'] = './HFCache'
os.environ['CUDA_VISIBLE_DEVICES'] = '7'

import ErrorDetector as ed
import importlib 
import os
importlib.reload(ed)

annos='../compose_nnUnet_ProGT/aorta/'


ed.SystematicComparisonLMDeploySepFigures(pth=annos,size=512,organ='aorta', dice_check=True,save_memory=True,solid_overlay=True,
                                          multi_image_prompt_2=True)
# Out:
# BDMAP_00003976_ct_window_bone_axis_1_aorta.png
# Best is: 2
# 2D dice coefficient between 2 projections on axis 1: 0.9713633060455322
# The projections are too similar for case {target}, skipping the comparison. Try another axis or ct compare slices (holes?).
# BDMAP_00000406_ct_window_bone_axis_1_aorta.png
# Best is: 2
# 2D dice coefficient between 2 projections on axis 1: 0.9656307697296143
# The projections are too similar for case {target}, skipping the comparison. Try another axis or ct compare slices (holes?).
# BDMAP_00004290_ct_window_bone_axis_1_aorta.png
# Best is: 1
# 2D dice coefficient between 2 projections on axis 1: 0.9227805137634277
# The projections are too similar for case {target}, skipping the comparison. Try another axis or ct compare slices (holes?).
# BDMAP_00000003_ct_window_bone_axis_1_aorta.png
# Best is: 2
# 2D dice coefficient between 2 projections on axis 1: 0.9828481078147888
# ...

# %% [markdown]
# # Systematic evaluation postcava

# %%
import os
os.environ['TRANSFORMERS_CACHE'] = './HFCache'
os.environ['HF_HOME'] = './HFCache'
os.environ['CUDA_VISIBLE_DEVICES'] = '7'

import ErrorDetector as ed
import importlib 
import os
importlib.reload(ed)

annos='/mnt/sdc/pedro/ErrorDetection/compose_BetaGT_ProGT/postcava/'



ed.SystematicComparison3MessagesLMDeploy2Figs(pth=annos,size=512,file_structure='new',organ='postcava', dice_check=True,save_memory=True,shuffle=True)

# %%
import os
os.environ['TRANSFORMERS_CACHE'] = './HFCache'
os.environ['HF_HOME'] = './HFCache'
os.environ['CUDA_VISIBLE_DEVICES'] = '7'

import ErrorDetector as ed
import importlib 
import os
importlib.reload(ed)

annos='/mnt/sdc/pedro/ErrorDetection/compose_nnUnet_ProGT/postcava/'



ed.SystematicComparison3MessagesLMDeploy2Figs(pth=annos,size=512,file_structure='new',organ='postcava', dice_check=True,save_memory=True,shuffle=True)

# %%
import os
os.environ['TRANSFORMERS_CACHE'] = './HFCache'
os.environ['HF_HOME'] = './HFCache'
os.environ['CUDA_VISIBLE_DEVICES'] = '7'

import ErrorDetector as ed
import importlib 
import os
importlib.reload(ed)

annos='/mnt/sdc/pedro/ErrorDetection/compose_nnUnet_ProGT/postcava/'



ed.SystematicComparison3MessagesLMDeploy2Figs(pth=annos,size=512,file_structure='new',organ='postcava', dice_check=True,save_memory=True,shuffle=True)
