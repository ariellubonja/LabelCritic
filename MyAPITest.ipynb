# %%
import os 
os.environ['CUDA_VISIBLE_DEVICES'] = '7'


import ErrorDetector as ed

# %%
ct='/mnt/sdc/pedro/ErrorDetection/cropped_liver_cts/BDMAP_00001399/ct.nii.gz'
y1='/mnt/sdc/pedro/ErrorDetection/cropped_liver_cts/BDMAP_00001399/segmentations/liver.nii.gz'
y2='../AbdomenAtlasBeta/BDMAP_00001399/segmentations/liver.nii.gz'

ed.project_and_compare(ct,y1,y2)
# Out:
# Organ projection of liver for patient ct is saved to ./tmp7806/ct_ct_axis_1_liver.png
# Organ projection of liver for patient y1_bone is saved to ./tmp7806/y1_bone_overlay_axis_1_liver.png
# Organ projection of liver for patient y1_organs is saved to ./tmp7806/y1_organs_overlay_axis_1_liver.png
# Organ projection of liver for patient y2_bone is saved to ./tmp7806/y2_bone_overlay_axis_1_liver.png
# Organ projection of liver for patient y2_organs is saved to ./tmp7806/y2_organs_overlay_axis_1_liver.png
# Composite image saved to ./tmp7806/composite_image_axis_1_liver.png
# Composite image saved to ./tmp7806/composite_image_2_figs_axis_1_liver.png
# Image resized to: (224, 81)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=356x130>
# Text: The image I am sending is frontal projections of one CT scan. It is not a CT slice, instead, they have transparency and let you see through the entire human body, like an X-ray does. Answer the questions below:
# ...
